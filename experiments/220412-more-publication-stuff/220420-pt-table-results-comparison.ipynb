# %%
from pathlib import Path

# %%
import pandas as pd

# %% [markdown]
# ## Setup

# %%
DATESTR = '220420'
NBNAME = DATESTR + '-pt-table-results-comparison'

# %%
infiles = dict(
    david_table=Path('data-src/220420-midas-pt-table.csv'),
    my_table=Path('data-processed/220419-set3-files-list/220419-200726-gold-standard-files.csv'),
    gambit=Path('data-src/220420-query-1.0-beta2.csv'),
)

# %%
processed_out = Path('data-processed') / NBNAME
processed_out.mkdir(exist_ok=True)

outfiles = dict(
    comp=processed_out / f'{DATESTR}-pt-table-results-comp.csv',
)

# %% [markdown]
# ## Code

# %%
def yesno_to_bool(x):
    if x == 'yes':
        return True
    elif x == 'no':
        return False
    raise ValueError(x)
    

def stripprefix(prefix, s, strict=True):
    if s.startswith(prefix):
        return s[len(prefix):]
    if strict:
        raise ValueError('String does not contain prefix')
    return s
    

def stripsuffix(suffix, s, strict=True):
    if s.endswith(suffix):
        return s[:-len(suffix)]
    if strict:
        raise ValueError('String does not contain suffix')
    return s

# %% [markdown]
# ## Load data

# %%
my_df = pd.read_csv(infiles['my_table'])

# %% [markdown]
# ### David

# %%
david = pd.read_csv(infiles['david_table'])

# %%
del david['jared_id needs edit']
david = david.set_index('jared_id')

# %%
david.columns = ['wgs_date', 'class', 'short_name', 'fastq_name', 'gambit_dist', 'gambit_sp_thresh', 'has_16s', 'gambit_genus', 'gambit_species', 'reported', 'cap']

# %%
david['has_16s'] = david['has_16s'].map(yesno_to_bool)

# %%
david.loc[david['gambit_species'] == 'none', 'gambit_species'] = None

# %%
david.loc[david['gambit_genus'] == 'none', 'gambit_genus'] = None

# %%
david['gambit_predicted'] = [row.gambit_genus if row.gambit_species is None else ' '.join([row.gambit_genus, row.gambit_species]) for _, row in david.iterrows()]

# %% [markdown]
# ### GAMBIT results

# %%
gambit = pd.read_csv(infiles['gambit'])

# %%
gambit = gambit.set_index('query.name')

# %% [markdown]
# ## Inspect

# %%
david.groupby('class').size()
# Out:
# class
# BACT1_2016    6
# BACT1_2017    6
# BACT1_2018    6
# BACT1_2019    6
# BACT1_2020    7
# BACT2_2017    7
# BACT2_2018    7
# BACT2_2019    8
# BACT3_2017    7
# BACT3_2018    8
# BACT3_2019    5
# LPX1 2017     3
# LPX1_2018     3
# LPX1_2019     3
# LPX2_2018     3
# LPX2_2019     3
# dtype: int64

# %%
david[david['has_16s']]
# Out:
#                  wgs_date       class               short_name  \
# jared_id
# 17AC0006313-1     6/29/17  BACT2_2017  17AC0006313-1_S23.fasta
# 18AC0018937-BAP  10/25/18  BACT3_2018          18AC0018937-BAP
# 19AC0011210        7/9/19  BACT2_2019           19AC0011210-W1
# 19AC0016708      10/17/19  BACT3_2019              19AC0016708
#
#                                             fastq_name  gambit_dist  \
# jared_id
# 17AC0006313-1      17AC0006313-1_S23_L001_R1_001.fastq        0.913
# 18AC0018937-BAP  18AC0018937-BAP_S11_L001_R1_001.fastq        0.942
# 19AC0011210           19AC0011210_S5_L001_R1_001.fastq        0.992
# 19AC0016708           19AC0016708_S8_L001_R1_001.fastq        0.325
#
#                  gambit_sp_thresh  has_16s gambit_genus gambit_species  \
# jared_id
# 17AC0006313-1               0.944     True  Veillonella           None
# 18AC0018937-BAP               NaN     True         None           None
# 19AC0011210                   NaN     True         None           None
# 19AC0016708                 0.921     True  Pseudomonas           None
#
#                                                           reported  \
# jared_id
# 17AC0006313-1    Veilonella genus with GAMBIT, V. parvula with 16S
# 18AC0018937-BAP                                   Proteus vulgaris
# 19AC0011210                                Granulicatella adiacens
# 19AC0016708      Pseudomonas putida group (species reported wit...
#
#                                                                cap  \
# jared_id
# 17AC0006313-1    Mixed Sample 2: Staphylococcus hominis and Vei...
# 18AC0018937-BAP                      Proteus sp / Proteus vulgaris
# 19AC0011210            Granulicatella sp / Granulicatella adiacens
# 19AC0016708      Pseudomonas sp/Pseudomonas putida /Pseudomonas...
#
#                 gambit_predicted
# jared_id
# 17AC0006313-1        Veillonella
# 18AC0018937-BAP             None
# 19AC0011210                 None
# 19AC0016708          Pseudomonas

# %%
david[(david['gambit_genus'] + ' ' + david['gambit_species']) != david['reported']]
# Out:
#                  wgs_date       class               short_name  \
# jared_id
# 17AC0001410       2/25/17  BACT1_2017        17AC0001410.fasta
# 17AC0001410A       3/4/17  BACT1_2017       17AC0001410A.fasta
# 17AC0006313-1     6/29/17  BACT2_2017  17AC0006313-1_S23.fasta
# 17AC0012453      10/26/17  BACT3_2017     17AC0012453_S1.fasta
# 17AC0012454      10/26/17  BACT3_2017     17AC0012454_S2.fasta
# 18AC0002826       2/23/18  BACT1_2018              18AC0002826
# 18AC0018937-BAP  10/25/18  BACT3_2018          18AC0018937-BAP
# 19AC0011210        7/9/19  BACT2_2019           19AC0011210-W1
# 19AC0016708      10/17/19  BACT3_2019              19AC0016708
# 19AC0016710      10/17/19  BACT3_2019              19AC0016710
#
#                                             fastq_name  gambit_dist  \
# jared_id
# 17AC0001410           17AC0001410_S9_L001_R1_001.fastq        0.161
# 17AC0001410A        17AC0001410A_S12_L001_R1_001.fastq        0.131
# 17AC0006313-1      17AC0006313-1_S23_L001_R1_001.fastq        0.913
# 17AC0012453           17AC0012453_S1_L001_R1_001.fastq        0.886
# 17AC0012454           17AC0012454_S2_L001_R1_001.fastq        0.019
# 18AC0002826          18AC0002826_S11_L001_R1_001.fastq        0.016
# 18AC0018937-BAP  18AC0018937-BAP_S11_L001_R1_001.fastq        0.942
# 19AC0011210           19AC0011210_S5_L001_R1_001.fastq        0.992
# 19AC0016708           19AC0016708_S8_L001_R1_001.fastq        0.325
# 19AC0016710          19AC0016710_S10_L001_R1_001.fastq        0.039
#
#                  gambit_sp_thresh  has_16s     gambit_genus gambit_species  \
# jared_id
# 17AC0001410                 0.347    False      Escherichia           coli
# 17AC0001410A                0.470    False     Enterococcus       faecalis
# 17AC0006313-1               0.944     True      Veillonella           None
# 17AC0012453                 0.928    False  Corynebacterium           None
# 17AC0012454                 0.937    False       Aerococcus           None
# 18AC0002826                 0.469    False    Streptococcus     agalactiae
# 18AC0018937-BAP               NaN     True             None           None
# 19AC0011210                   NaN     True             None           None
# 19AC0016708                 0.921     True      Pseudomonas           None
# 19AC0016710                 0.522    False    Streptococcus       pyogenes
#
#                                                           reported  \
# jared_id
# 17AC0001410      Negative for E coli O157/Aeromonas/Campylobact...
# 17AC0001410A     Negative for E coli O157/Aeromonas/Campylobact...
# 17AC0006313-1    Veilonella genus with GAMBIT, V. parvula with 16S
# 17AC0012453                                     Corynebacterium sp
# 17AC0012454                                          Aerococcus sp
# 18AC0002826      Streptococcus agalactiae group B /Finegoldia m...
# 18AC0018937-BAP                                   Proteus vulgaris
# 19AC0011210                                Granulicatella adiacens
# 19AC0016708      Pseudomonas putida group (species reported wit...
# 19AC0016710                                Streptococcus pyogenes
#
#                                                                cap  \
# jared_id
# 17AC0001410      Mixed Sample 1: Exclude E coli O157/Aeromonas/...
# 17AC0001410A     Mixed Sample 1: Exclude E coli O157/Aeromonas/...
# 17AC0006313-1    Mixed Sample 2: Staphylococcus hominis and Vei...
# 17AC0012453           Corynebacterium sp /Corynebacterium striatum
# 17AC0012454                     Aerococcus sp/ Aerococcus viridans
# 18AC0002826      Streptococcus agalactiae group B /Finegoldia m...
# 18AC0018937-BAP                      Proteus sp / Proteus vulgaris
# 19AC0011210            Granulicatella sp / Granulicatella adiacens
# 19AC0016708      Pseudomonas sp/Pseudomonas putida /Pseudomonas...
# 19AC0016710                                Streptococcus pyogenes
#
#                          gambit_predicted
# jared_id
# 17AC0001410              Escherichia coli
# 17AC0001410A        Enterococcus faecalis
# 17AC0006313-1                 Veillonella
# 17AC0012453               Corynebacterium
# 17AC0012454                    Aerococcus
# 18AC0002826      Streptococcus agalactiae
# 18AC0018937-BAP                      None
# 19AC0011210                          None
# 19AC0016708                   Pseudomonas
# 19AC0016710        Streptococcus pyogenes

# %% [markdown]
# ## Compare to latest GAMBIT results

# %%
left = david[['gambit_dist', 'gambit_sp_thresh', 'gambit_genus', 'gambit_species', 'reported', 'cap', 'gambit_predicted']]
left.columns = ['pt_' + n for n in left.columns]

# %%
right = gambit.copy()
del right['query.path']
right.columns = ['new_' + n for n in right.columns]
right.index.name = 'jared_id'

# %%
comp = left.join(right, on='jared_id')

# %%
matches = comp['new_predicted.name'] == comp['pt_gambit_predicted']
matches |= pd.isnull(comp['new_predicted.name']) & pd.isnull(comp['pt_gambit_predicted'])

# %%
comp[~matches]
# Out:
#                  pt_gambit_dist  pt_gambit_sp_thresh  \
# jared_id
# 16AC1611140BCAP           0.337                0.554
#
#                                    pt_gambit_genus pt_gambit_species  \
# jared_id
# 16AC1611140BCAP  Propionibacterium (Cutibacterium)             acnes
#
#                                              pt_reported             pt_cap  \
# jared_id
# 16AC1611140BCAP  Propionibacterium (Cutibacterium) acnes  Propionibacterium
#
#                                      pt_gambit_predicted   new_predicted.name  \
# jared_id
# 16AC1611140BCAP  Propionibacterium (Cutibacterium) acnes  Cutibacterium acnes
#
#                 new_predicted.rank  new_predicted.ncbi_id  \
# jared_id
# 16AC1611140BCAP            species                 1747.0
#
#                  new_predicted.threshold  new_closest.distance  \
# jared_id
# 16AC1611140BCAP                 0.553531              0.337403
#
#                                            new_closest.description  \
# jared_id
# 16AC1611140BCAP  [GCF_000145115.1] Cutibacterium acnes HL030PA1...
#
#                 new_next.name new_next.rank  new_next.ncbi_id  \
# jared_id
# 16AC1611140BCAP           NaN           NaN               NaN
#
#                  new_next.threshold
# jared_id
# 16AC1611140BCAP                 NaN

# %% [markdown]
# ## Write output

# %%
comp.to_csv(outfiles['comp'])
