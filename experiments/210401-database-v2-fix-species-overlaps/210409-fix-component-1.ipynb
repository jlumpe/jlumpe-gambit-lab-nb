# %% [markdown]
# # 210409 Fix component 1

# %%
const COMPONENT = 1;

# %%
include("fix-component-base.jl");
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-3926808757134330869\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-5436033943498372384\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-3926808757134330869\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# 34×14 DataFrame
#  Row │ id     ncbi_id  name                            rank     parent_id  in_v12  manual_threshold  report  ngenomes  comp_idx  diameter     outgoing  incoming  name_abbr
#      │ Int64  Int64?   String                          String?  Int64?     Bool    Float64           Bool    Int64     Int64     Float32      Int64     Int64     SubStrin…
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │  1086     1912  Streptomyces hygroscopicus      species        443    true              NaN     true         6        19  0.960201           33         1  hygroscopicus
#    2 │  1076     1888  Streptomyces albus              species        443    true              NaN     true         6        12  0.956074           28         1  albus
#    3 │  1061    67351  Streptomyces californicus       species        443    true              NaN     true         5         8  0.316231            1         2  californicus
#    4 │   786    33903  Streptomyces avermitilis        species        443    true              NaN     true         4         1  0.150675            0         2  avermitilis
#    5 │   827    42234  Streptomyces acidiscabies       species        443    true              NaN     true         3         2  0.453792            0         1  acidiscabies
#    6 │   831    42235  Streptomyces bottropensis       species        443    true              NaN     true         2         3  0.00103324          0         2  bottropensis
#    7 │   870    66874  Streptomyces bicolor            species        443    true              NaN     true         2         4  0.0214534           0         2  bicolor
#    8 │   918    83378  Streptomyces ruber              species        443    true              NaN     true         2         5  0.0206039           0         2  ruber
#    9 │  1033    67275  Streptomyces aureocirculatus    species        443    true              NaN     true         2         6  0.00165207          0         2  aureocirculatus
#   10 │  1040    67294  Streptomyces filamentosus       species        443    true              NaN     true         2         7  0.0216551           0         2  filamentosus
#   11 │  1062    67356  Streptomyces resistomycificus   species        443    true              NaN     true         3         9  0.0108258           0         2  resistomycificus
#   ⋮  │   ⋮       ⋮                   ⋮                    ⋮         ⋮        ⋮            ⋮            ⋮        ⋮         ⋮           ⋮          ⋮         ⋮              ⋮
#   25 │  1203    68242  Streptomyces natalensis         species        443    true              NaN     true         2        25  0.0230369           0         1  natalensis
#   26 │  1254    68570  Streptomyces albulus            species        443    true              NaN     true         4        26  0.204046            0         2  albulus
#   27 │  1299  1355015  Streptomyces pluripotens        species        443    true              NaN     true         2        27  0.489903            0         1  pluripotens
#   28 │  1375    85558  Streptomyces turgidiscabies     species        443    true              NaN     true         2        28  0.0348497           0         2  turgidiscabies
#   29 │  1392   249567  Streptomyces decoyicus          species        443    true              NaN     true         2        29  0.0179845           0         1  decoyicus
#   30 │  1397  1437453  Streptomyces leeuwenhoekii      species        443    true              NaN     true         3        30  0.325781            0         2  leeuwenhoekii
#   31 │  1621    54571  Streptomyces venezuelae         species        443    true              NaN     true         2        31  0.000176991         0         2  venezuelae
#   32 │  1631    38300  Streptomyces pristinaespiralis  species        443    true              NaN     true         2        32  0.0398469           0         2  pristinaespiralis
#   33 │  1841   146819  Streptomyces europaeiscabiei    species        443    true              NaN     true         3        33  0.240434            0         2  europaeiscabiei
#   34 │  1843   146820  Streptomyces stelliscabiei      species        443    true              NaN     true         2        34  0.0385186           0         2  stelliscabiei
#                                                                                                                                                                      13 rows omitted
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.9501239869335272cx, -0.26803938620021184cy), (-0.689730687471158cx, -0.7329277249285687cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.551679569684308cx, 0.3035951097789973cy), (-0.9305349609148359cx, -0.10421934430737534cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.41753757053659635cx, 0.2994170569670678cy), (-0.018741402623215636cx, -0.18740400843382599cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.4066977212460431cx, 0.44702762687497444cy), (0.1260015377320297cx, 0.9313423116337718cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.49550415165253325cx, 0.27717679329167144cy), (-0.6265650533512958cx, -0.7207797928745815cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.05577234530489639cx, -0.25786164506807074cy), (-0.8982920972557717cx, -0.18748941794455798cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.018741402623215636cx, -0.18740400843382599cy), (-0.4175375705365964cx, 0.2994170569670678cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.058381180436754165cx, -0.16505647963639128cy), (0.1890727240877082cx, 0.8986995896608868cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.12684275629765784cx, -0.32857177436474017cy), (0.919092801141674cx, -0.9377851156107643cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.033366068080360925cx, -0.3306057721183175cy), (-0.5605530488849924cx, -0.7577240559488432cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.2247448713915892mm)]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.0,0.0,0.0,0.0))]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.8274509803921568,0.8274509803921568,0.8274509803921568,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7654918159877604cx, -0.6676571235379668cy), (-0.689730687471158cx, -0.7329277249285687cy), (-0.7058119451250562cx, -0.6342292287279226cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.891635802810318cx, -0.012095213381978165cy), (-0.9305349609148359cx, -0.10421934430737534cy), (-0.8415202270948776cx, -0.05865206259163147cy)]), Compose.LinePrimitive{T ...
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, marker, mode, type, x, and y"
# ]
#
# layout: "layout with fields height, margin, width, and xaxis"

# %%
trees = Dict{String, Any}();

# %% [markdown]
# ## Edits

# %% [markdown]
# ### hygroscopicus

# %%
let taxon = "hygroscopicus"
    trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, trees[taxon]))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
set_threshold!(edits, "hygroscopicus", 0.6);

# %% [markdown]
# ### albus

# %%
let taxon = "albus"
    trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, trees[taxon]))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
set_threshold!(edits, "albus", 0.6);

# %% [markdown]
# ### californicus/griseus

# %%
let taxon = "californicus"
    trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, trees[taxon]))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
let taxon = "griseus"
    trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, trees[taxon]))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
plot(multi_clustermap(cdata, ["californicus", "griseus"]))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "heatmap with fields colorscale, customdata, hovertemplate, showscale, type, xaxis, y, ygap, z, zmax, and zmin"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, xaxis3, and yaxis"

# %%
set_threshold!(edits, "californicus", 0.2)
# Out:
# 0.2

# %% [markdown]
# ## Finish

# %%
complete_edits(edits)
# Out:
# 3×9 DataFrame
#  Row │ index  name           ngenomes  initial_diameter  taxon_removed  removed_genomes  split   manual_threshold  final_diameter
#      │ Int64  SubStrin…      Int64     Float32           Bool           Int64            String  Float64?          String
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │     8  californicus          5          0.316231          false                0                       0.2  0.3162
#    2 │    12  albus                 6          0.956074          false                0                       0.6  0.9561
#    3 │    19  hygroscopicus         6          0.960201          false                0                       0.6  0.9602
