# %% [markdown]
# # 210420 Fix Component 2

# %%
const COMPONENT = 2;

# %%
include("fix-component-base.jl");
include("fix-component-base-ext.jl");
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-13882701372143545018\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-9962385022656160996\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...

# %%
trees = Dict{String, Any}();

# %% [markdown]
# ## Edits

# %% [markdown]
# ### fluorescens

# %%
let taxon = "fluorescens"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
set_threshold!(edits, "fluorescens", .8)
# Out:
# 0.8

# %% [markdown]
# ### parafulva

# %%
let taxon = "parafulva"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
set_threshold!(edits, "parafulva", .6)
# Out:
# 0.6

# %% [markdown]
# ### alcaligenes

# %%
let taxon = "alcaligenes"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
set_threshold!(edits, "alcaligenes", .8)
# Out:
# 0.8

# %% [markdown]
# ### syringae/amygdali/savastanoi group

# %%
plot(multi_clustermap(cdata, ["syringae", "amygdali", "savastanoi"]))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
let taxon = "syringae"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
split_taxon!(edits, trees["syringae"], [219, 211, 225, 216])
# Out:
# Subgroup 1 size: 51
# Subgroup 2 size: 19
# Subgroup 3 size: 33
# Subgroup 4 size: 7
# Genomes to delete: 4

# %%
plot(multi_clustermap(cdata, ["amygdali", "savastanoi"]))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %% [markdown]
# ### amygdali

# %%
let taxon = "amygdali"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
split_taxon!(edits, trees["amygdali"], [54, 53, 50])
# Out:
# Subgroup 1 size: 8
# Subgroup 2 size: 8
# Subgroup 3 size: 11
# Genomes to delete: 2

# %% [markdown]
# ### savastanoi

# %%
let taxon = "savastanoi"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
split_taxon!(edits, trees["savastanoi"], [44, 46])
# Out:
# Subgroup 1 size: 9
# Subgroup 2 size: 15
# Genomes to delete: 0

# %% [markdown]
# ### putida/monteilii

# %%
plot(multi_clustermap(cdata, ["putida", "monteilii"]))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
let taxon = "putida"
    tree = trees[taxon] = cluster_annotate(cdata, taxon)
    plot(clustermap(cdata, tree))
end
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
split_taxon!(edits, trees["putida"], [52, 49, 53])
# Out:
# Subgroup 1 size: 18
# Subgroup 2 size: 4
# Subgroup 3 size: 6
# Genomes to delete: 0

# %% [markdown]
# ### aeruginosa/denitrificans

# %%
plot(multi_clustermap(cdata, ["aeruginosa", "denitrificans (nom. rej.)"]))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields fill, hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
# ...

# %%
remove_taxon!(edits, "denitrificans (nom. rej.)")

# %% [markdown]
# ## Additional edits

# %%
cdata2 = apply_edits(edits);
edits2 = DatabaseEdits(cdata2);

OverlapAnalysis.print_overlaps(cdata2)
# Out:
# #11 syringae subgroup 4
# 	=> #22 savastanoi subgroup 1
# 	=> #32 amygdali subgroup 2
# 	=> #33 amygdali subgroup 3
# #32 amygdali subgroup 2
# 	=> #11 syringae subgroup 4
# 	=> #22 savastanoi subgroup 1

# %%
plot(clustermap(cdata2, "syringae subgroup 4"))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# layout: "layout with fields height, hovermode, margin, showlegend, width, xaxis, xaxis2, and yaxis"

# %%
set_threshold!(edits2, "syringae subgroup 4", .25)
# Out:
# 0.25

# %%
plot(clustermap(cdata2, "amygdali subgroup 2"))
# Out:
# data: [
#   "heatmap with fields colorscale, type, x, y, and z",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hoverinfo, line, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields customdata, hovertemplate, marker, mode, showlegend, type, x, xaxis, y, and yaxis",
#   "scatter with fields hovertemplate, marker, mode, text, type, x, xaxis, and y"
# ]
#
# ...

# %%
set_threshold!(edits2, "amygdali subgroup 2", .25)
# Out:
# 0.25

# %% [markdown]
# ## Finish

# %%
complete_edits(edits, edits2)
# Out:
# 7×9 DataFrame
#  Row │ index  name         ngenomes  initial_diameter  taxon_removed  removed_genomes  split          manual_threshold  final_diameter
#      │ Int64  SubStrin…    Int64     Float32           Bool           Int64            String         Float64?          String
# ─────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │     2  fluorescens        38          0.976624          false                0                              0.8  0.9766
#    2 │     5  putida             28          0.886751          false                0  18, 4, 6              missing    0.7105, 0.5615, 0.7793
#    3 │     6  syringae          114          0.915752          false                4  51, 19, 33, 7         missing    0.4567, 0.3568, 0.7149, 0.3883
#    4 │     8  parafulva           4          0.941948          false                0                              0.6  0.9419
# ...
