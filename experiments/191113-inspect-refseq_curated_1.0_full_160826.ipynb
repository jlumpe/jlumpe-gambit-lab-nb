# %%
from pathlib import Path
import json

# %%
datadir = Path('/Users/student/projects/midas/data/refseq_curated_1.0_full_160826/')

# %% [markdown]
# ## Refseq

# %%
with open(datadir / 'genome_sets/refseq/assembly/all') as f:
    refseqdata = json.load(f)

# %%
print(refseqdata['name'])
print(refseqdata['key'], data['key_version'])
print(refseqdata['description'])
# Out:
# refseq
# refseq/assembly/all 1.0
# All bacterial RefSeq entries in assembly database

# %%
len(refseqdata['annotations'].items())
# Out:
# 65563

# %% [markdown]
# ## MIDAS

# %%
with open(datadir / 'genome_sets/midas/assembly/curated') as f:
    midasdata = json.load(f)

# %%
print(midasdata['name'])
print(midasdata['key'], data['key_version'])
print(midasdata['description'])
# Out:
# refseq_curated
# midas/assembly/curated 1.0
# None

# %%
len(midasdata['annotations'].items())
# Out:
# 51132

# %% [markdown]
# ## Compare

# %%
refseqkeys = set(refseqdata['annotations'].keys())

# %%
midaskeys = set(midasdata['annotations'].keys())

# %%
midaskeys.issubset(refseqkeys)
# Out:
# True

# %%
diffkeys = [k for k in midaskeys if refseqdata['annotations'][k] != midasdata['annotations'][k]]
len(diffkeys)
# Out:
# 213

# %%
for k in sorted(diffkeys):
    print(k)
    d1 = dict(refseqdata['annotations'][k])
    d2 = dict(midasdata['annotations'][k])
    for k2 in sorted(d1):
        if d1[k2] != d2[k2]:
            print('  ' + k2)
            print('    ' + d1[k2])
            print('    ' + d2[k2])
# Out:
# refseq/assembly/GCF_000007805.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000015785.1
#   tax_species
#     velezensis
#     amyloliquefaciens
# refseq/assembly/GCF_000146405.1
#   tax_species
#     equinus
#     pasteurianus
# refseq/assembly/GCF_000155515.2
#   tax_species
#     paracasei
#     casei
# refseq/assembly/GCF_000161095.1
#   tax_species
#     cereus
#     weihenstephanensis
# refseq/assembly/GCF_000172895.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000177455.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000177475.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000177495.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000234175.1
#   tax_species
#     saccharolyticus
#     gallinarum
# refseq/assembly/GCF_000250775.1
#   tax_species
#     melitensis
#     suis
# refseq/assembly/GCF_000250835.1
#   tax_species
#     melitensis
#     abortus
# refseq/assembly/GCF_000262385.1
#   tax_species
#     amyloliquefaciens
#     velezensis
# refseq/assembly/GCF_000286655.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000290795.1
#   tax_species
#     cereus
#     thuringiensis
# refseq/assembly/GCF_000292125.1
#   tax_species
#     suis
#     melitensis
# refseq/assembly/GCF_000298055.1
#   tax_species
#     hydrophila
#     dhakensis
# refseq/assembly/GCF_000309645.1
#   tax_species
#     casei
#     paracasei
# refseq/assembly/GCF_000309665.1
#   tax_species
#     casei
#     paracasei
# refseq/assembly/GCF_000309685.1
#   tax_species
#     casei
#     paracasei
# refseq/assembly/GCF_000309785.1
#   tax_species
#     casei
#     paracasei
# refseq/assembly/GCF_000341835.1
#   tax_species
#     calcoaceticus
#     pittii
# refseq/assembly/GCF_000348585.1
#   tax_species
#     axonopodis
#     citri
# refseq/assembly/GCF_000420505.1
#   tax_genus
#     Alloscardovia
#     Gardnerella
#   tax_species
#     omnicolens
#     vaginalis
# refseq/assembly/GCF_000425925.1
#   tax_species
#     arenicola
#     tropica
# refseq/assembly/GCF_000427485.1
#   tax_species
#     meliloti
#     medicae
# refseq/assembly/GCF_000428625.1
#   tax_species
#     arginini
#     synoviae
# refseq/assembly/GCF_000466365.1
#   tax_genus
#     Alloscardovia
#     Gardnerella
#   tax_species
#     omnicolens
#     vaginalis
# refseq/assembly/GCF_000467655.2
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000468975.2
#   tax_species
#     thuringiensis
#     cereus
# refseq/assembly/GCF_000469645.1
#   tax_species
#     rhodochrous
#     erythropolis
# refseq/assembly/GCF_000473025.1
#   tax_species
#     japonicum
#     diazoefficiens
# refseq/assembly/GCF_000478345.1
#   tax_species
#     cancerogenus
#     hormaechei
# refseq/assembly/GCF_000492895.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000493175.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000504545.1
#   tax_species
#     sakazakii
#     malonaticus
# refseq/assembly/GCF_000520915.1
#   tax_species
#     subtilis
#     cereus
# refseq/assembly/GCF_000523595.1
#   tax_species
#     avium
#     intracellulare
# refseq/assembly/GCF_000523895.1
#   tax_species
#     chelonae
#     abscessus
# refseq/assembly/GCF_000534155.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000580855.1
#   tax_species
#     sp. 1289694
#     pittii
# refseq/assembly/GCF_000580955.1
#   tax_species
#     sp. 1475718
#     pittii
# refseq/assembly/GCF_000581095.1
#   tax_species
#     sp. 1295259
#     pittii
# refseq/assembly/GCF_000582075.1
#   tax_species
#     sp. 1578804
#     pittii
# refseq/assembly/GCF_000582195.1
#   tax_species
#     sp. 907131
#     pittii
# refseq/assembly/GCF_000583395.1
#   tax_species
#     sp. 263903-2
#     pittii
# refseq/assembly/GCF_000584015.1
#   tax_species
#     sp. 478810
#     pittii
# refseq/assembly/GCF_000584215.1
#   tax_species
#     sp. 723929
#     pittii
# refseq/assembly/GCF_000584615.1
#   tax_species
#     sp. 1245593
#     nosocomialis
# refseq/assembly/GCF_000588395.1
#   tax_species
#     sp. 883425
#     pittii
# refseq/assembly/GCF_000588415.1
#   tax_species
#     sp. 225588
#     pittii
# refseq/assembly/GCF_000588595.1
#   tax_species
#     sp. 1281984
#     nosocomialis
# refseq/assembly/GCF_000591535.1
#   tax_species
#     parahaemolyticus
#     alginolyticus
# refseq/assembly/GCF_000612205.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000633915.1
#   tax_species
#     monteilii
#     putida
# refseq/assembly/GCF_000666625.1
#   tax_species
#     africanum
#     tuberculosis
# refseq/assembly/GCF_000677255.1
#   tax_species
#     tuberculosis
#     bovis
# refseq/assembly/GCF_000681535.1
#   tax_species
#     baumannii
#     pittii
# refseq/assembly/GCF_000681815.1
#   tax_species
#     sp. 1264765
#     pittii
# refseq/assembly/GCF_000682355.1
#   tax_species
#     sp. 72431
#     pittii
# refseq/assembly/GCF_000692295.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000692335.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000699685.1
#   tax_species
#     fragilis
#     ovatus
# refseq/assembly/GCF_000717535.1
#   tax_species
#     thuringiensis
#     cereus
# refseq/assembly/GCF_000719995.1
#   tax_species
#     opacus
#     erythropolis
# refseq/assembly/GCF_000721155.1
#   tax_species
#     lavendulae
#     rimosus
# refseq/assembly/GCF_000733495.1
#   tax_species
#     michiganensis
#     oxytoca
# refseq/assembly/GCF_000736955.1
#   tax_species
#     cholerae
#     mimicus
# refseq/assembly/GCF_000746375.1
#   tax_species
#     calcoaceticus
#     pittii
# refseq/assembly/GCF_000750045.1
#   tax_species
#     amyloliquefaciens
#     velezensis
# refseq/assembly/GCF_000755725.1
#   tax_species
#     cenocepacia
#     pseudomultivorans
# refseq/assembly/GCF_000765305.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000769515.1
#   tax_species
#     subtilis
#     amyloliquefaciens
# refseq/assembly/GCF_000775205.1
#   tax_species
#     axonopodis
#     fuscans
# refseq/assembly/GCF_000786915.1
#   tax_species
#     axonopodis
#     fuscans
# refseq/assembly/GCF_000787015.1
#   tax_species
#     baumannii
#     pittii
# refseq/assembly/GCF_000802685.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_000805795.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_000812825.1
#   tax_species
#     odoratimimus
#     marinus
# refseq/assembly/GCF_000827145.1
#   tax_species
#     casei
#     paracasei
# refseq/assembly/GCF_000832885.1
#   tax_species
#     thuringiensis
#     mycoides
# refseq/assembly/GCF_000834215.1
#   tax_species
#     frederiksenii
#     kristensenii
# refseq/assembly/GCF_000835235.1
#   tax_species
#     thuringiensis
#     cereus
# refseq/assembly/GCF_000877315.1
#   tax_species
#     cepacia
#     cenocepacia
# refseq/assembly/GCF_000934645.1
#   tax_species
#     amygdali Psallidas and Panagopoulos 1975
#     amygdali
# refseq/assembly/GCF_000935665.1
#   tax_species
#     amygdali
#     syringae
# refseq/assembly/GCF_000935725.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000935765.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_000949365.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000950315.1
#   tax_species
#     damselae
#     angustum
# refseq/assembly/GCF_000952195.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952215.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952275.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952285.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952355.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952405.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952415.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952455.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952475.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952495.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952505.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952515.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952555.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952585.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952595.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952655.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952665.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952675.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000952755.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000956985.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_000958485.1
#   tax_species
#     paracasei
#     casei
# refseq/assembly/GCF_000958665.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958695.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958725.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958745.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958765.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958815.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958825.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958845.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000958925.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_000959975.1
#   tax_species
#     mitis
#     oralis
# refseq/assembly/GCF_000960035.1
#   tax_species
#     mitis
#     oralis
# refseq/assembly/GCF_000963285.1
#   tax_species
#     sanguinis
#     parasanguinis
# refseq/assembly/GCF_000972175.1
#   tax_species
#     syringae pv. coryli
#     syringae
# refseq/assembly/GCF_000974835.2
#   tax_species
#     cepacia
#     dolosa
# refseq/assembly/GCF_000980905.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001010875.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_001011725.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_001017635.1
#   tax_species
#     thuringiensis
#     cereus
# refseq/assembly/GCF_001022435.2
#   tax_species
#     ludwigii
#     cloacae
# refseq/assembly/GCF_001022875.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_001025045.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_001025055.1
#   tax_species
#     cloacae
#     hormaechei
# refseq/assembly/GCF_001029875.1
#   tax_species
#     anthracis
#     cereus
# refseq/assembly/GCF_001030745.1
#   tax_species
#     oxytoca
#     pneumoniae
# refseq/assembly/GCF_001052595.1
#   tax_genus
#     Enterobacter
#     Klebsiella
#   tax_species
#     cloacae
#     pneumoniae
# refseq/assembly/GCF_001053555.1
#   tax_species
#     propinquum
#     aurimucosum
# refseq/assembly/GCF_001054395.1
#   tax_species
#     propinquum
#     aurimucosum
# refseq/assembly/GCF_001054455.1
#   tax_species
#     influenzae
#     parainfluenzae
# refseq/assembly/GCF_001056435.1
#   tax_species
#     cenocepacia
#     multivorans
# refseq/assembly/GCF_001059125.1
#   tax_species
#     influenzae
#     parainfluenzae
# refseq/assembly/GCF_001060205.1
#   tax_species
#     denitrificans
#     aeruginosa
# refseq/assembly/GCF_001060395.1
#   tax_species
#     denitrificans
#     aeruginosa
# refseq/assembly/GCF_001060405.1
#   tax_species
#     michiganensis
#     oxytoca
# refseq/assembly/GCF_001060745.1
#   tax_species
#     denitrificans
#     aeruginosa
# refseq/assembly/GCF_001061115.1
#   tax_genus
#     Shigella
#     Escherichia
#   tax_species
#     boydii
#     coli
# refseq/assembly/GCF_001063435.1
#   tax_species
#     denitrificans
#     aeruginosa
# refseq/assembly/GCF_001064305.1
#   tax_species
#     aeruginosa
#     denitrificans
# refseq/assembly/GCF_001065515.1
#   tax_species
#     aeruginosa
#     denitrificans
# refseq/assembly/GCF_001066615.1
#   tax_species
#     aeruginosa
#     denitrificans
# refseq/assembly/GCF_001067805.1
#   tax_species
#     denitrificans
#     aeruginosa
# refseq/assembly/GCF_001067815.1
#   tax_species
#     denitrificans
#     aeruginosa
# refseq/assembly/GCF_001068835.1
#   tax_species
#     pseudopneumoniae
#     mitis
# refseq/assembly/GCF_001071265.1
#   tax_species
#     cenocepacia
#     multivorans
# refseq/assembly/GCF_001071965.1
#   tax_species
#     warneri
#     caprae
# refseq/assembly/GCF_001077735.1
#   tax_species
#     amyloliquefaciens
#     velezensis
# refseq/assembly/GCF_001140625.1
#   tax_species
#     pseudotuberculosis
#     similis
# refseq/assembly/GCF_001188525.1
#   tax_species
#     licheniformis
#     paralicheniformis
# refseq/assembly/GCF_001222425.1
#   tax_species
#     intermedia
#     pseudotuberculosis
# refseq/assembly/GCF_001270585.1
#   tax_species
#     griseoflavus
#     rimosus
# refseq/assembly/GCF_001270665.1
#   tax_species
#     aureofaciens
#     rimosus
# refseq/assembly/GCF_001278955.1
#   tax_species
#     tequilensis
#     subtilis
# refseq/assembly/GCF_001280585.1
#   tax_species
#     japonicum
#     diazoefficiens
# refseq/assembly/GCF_001280625.1
#   tax_species
#     parahaemolyticus
#     alginolyticus
# refseq/assembly/GCF_001281565.1
#   tax_species
#     vulgaris
#     mirabilis
# refseq/assembly/GCF_001291565.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001291625.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001291645.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001291685.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001291705.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001291945.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001292205.1
#   tax_species
#     coli
#     jejuni
# refseq/assembly/GCF_001292265.1
#   tax_species
#     coli
#     jejuni
# refseq/assembly/GCF_001292465.1
#   tax_species
#     jejuni
#     coli
# refseq/assembly/GCF_001292485.1
#   tax_species
#     coli
#     jejuni
# refseq/assembly/GCF_001293855.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001293975.1
#   tax_species
#     amygdali
#     savastanoi
# refseq/assembly/GCF_001294165.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001294185.1
#   tax_species
#     syringae group genomosp. 3
#     savastanoi
# refseq/assembly/GCF_001294305.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001391695.1
#   tax_species
#     tuberculosis
#     bovis
# refseq/assembly/GCF_001394175.1
#   tax_species
#     tuberculosis
#     bovis
# refseq/assembly/GCF_001394395.1
#   tax_species
#     tuberculosis
#     bovis
# refseq/assembly/GCF_001394575.1
#   tax_species
#     tuberculosis
#     bovis
# refseq/assembly/GCF_001395695.1
#   tax_species
#     tuberculosis
#     bovis
# refseq/assembly/GCF_001400235.1
#   tax_species
#     syringae pv. coryli
#     syringae
# refseq/assembly/GCF_001400595.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001400755.1
#   tax_species
#     amygdali
#     savastanoi
# refseq/assembly/GCF_001400855.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001401095.1
#   tax_species
#     amygdali Psallidas and Panagopoulos 1975
#     amygdali
# refseq/assembly/GCF_001401135.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001401165.1
#   tax_species
#     amygdali Psallidas and Panagopoulos 1975
#     amygdali
# refseq/assembly/GCF_001401175.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001401385.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001401395.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001401405.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001433045.1
#   tax_species
#     nosocomialis
#     baumannii
# refseq/assembly/GCF_001433735.1
#   tax_species
#     casei
#     paracasei
# refseq/assembly/GCF_001471615.1
#   tax_species
#     sp. FDAARGOS_131
#     nosocomialis
# refseq/assembly/GCF_001507755.1
#   tax_species
#     licheniformis
#     paralicheniformis
# refseq/assembly/GCF_001507765.1
#   tax_species
#     licheniformis
#     paralicheniformis
# refseq/assembly/GCF_001518465.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001518695.1
#   tax_species
#     syringae group genomosp. 3
#     syringae
# refseq/assembly/GCF_001524995.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_001535915.1
#   tax_species
#     amygdali Psallidas and Panagopoulos 1975
#     amygdali
# refseq/assembly/GCF_001546145.1
#   tax_genus
#     Alloscardovia
#     Gardnerella
#   tax_species
#     omnicolens
#     vaginalis
# refseq/assembly/GCF_001580105.1
#   tax_species
#     cellulosilyticus
#     fragilis
# refseq/assembly/GCF_001631035.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_001631425.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_001631455.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_001631485.1
#   tax_species
#     hormaechei
#     cloacae
# refseq/assembly/GCF_001631695.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
# refseq/assembly/GCF_001631745.1
#   tax_species
#     cloacae complex 'Hoffmann cluster IV'
#     asburiae
