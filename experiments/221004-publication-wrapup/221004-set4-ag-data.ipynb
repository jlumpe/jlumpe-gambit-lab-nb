# %% [markdown]
# # 221004 Set4 AG Data

# %%
from pathlib import Path

# %%
import pandas as pd

# %% [markdown]
# ## Setup

# %%
DATESTR = '221004'
NBNAME = f'{DATESTR}-set4-ag-data'

# %%
infiles = dict(
    set4=Path('~/code/gambit/gambit-publication/resources/genomes/set4/genomes.csv'),
    ag=Path('src/220923-GAMBIT-Species-ID-Comparison-AG.xlsx'),
)

# %%
data_processed = Path('data-processed') / NBNAME
data_processed.mkdir(exist_ok=True)

outfiles = dict(
    table=data_processed / f'{DATESTR}-ag-data.csv',
)

# %% [markdown]
# ## Load data

# %%
set4 = pd.read_csv(infiles['set4'], index_col=0)
assert set4.index.is_unique

# %%
ag = pd.read_excel(infiles['ag'], sheet_name=2)

del ag['Temp']  # Don't think this means anything

ag = ag.astype({
    'entity:miniseq_id': str,
    'genome_length': pd.Int64Dtype(),
})

ag.set_index('entity:miniseq_id', inplace=True)
assert ag.index.is_unique

# %% [markdown]
# ## Match up rows

# %%
id_map = {gid: gid for gid in set4.index if gid in ag.index}
len(id_map), set4.shape[0]
# Out:
# (603, 605)

# %%
set4[~set4.index.isin(id_map.values())]
# Out:
#               n_contigs  total_length     N50  L50  \
# id
# 21-00368644A         47       5043096  418498    5
# 21-00368644B         70       1665864   78104    8
#
#                                            md5               filename
# id
# 21-00368644A  d68d05ae6b8a83d9836eb5d4518bc2f2  21-00368644A.fasta.gz
# 21-00368644B  8b06a215189922bbf644004cd758d3a5  21-00368644B.fasta.gz

# %%
ag[ag.index.str.startswith('21-00368644')]
# Out:
#                   biosample_accession     submission_id  \
# entity:miniseq_id
# 21-00368644              SAMN30861796  NV_NSPHL_0000329
# 21-00368644b                      NaN               NaN
#
#                                              amrfinderplus_amr_genes  \
# entity:miniseq_id
# 21-00368644        oqxA,oqxB,aph(3')-Ia,fosA,blaACT-17,blaKPC-2,b...
# 21-00368644b                                                  blaOXA
#
#                   ts_mlst_predicted_st gambit_predicted_taxon           city  \
# entity:miniseq_id
# 21-00368644                      ST204   Campylobacter jejuni  not collected
# 21-00368644b                      ST50   Campylobacter jejuni            NaN
#
#                   received_date Provider collection_date  \
# entity:miniseq_id
# 21-00368644          2021-06-21    Lemak      2021-06-17
# 21-00368644b                NaT      NaN             NaT
#
#                                              dataset  ...  isolation_type  \
# entity:miniseq_id                                     ...
# 21-00368644                  368644-NV-A01307-210721  ...        Clinical
# 21-00368644b       CL2021-00368644-NV-MN01149-210701  ...             NaN
#
#                          lat_lon        library_ID library_layout  \
# entity:miniseq_id
# 21-00368644        not collected  NV_NSPHL_0000329         paired
# 21-00368644b                 NaN               NaN            NaN
#
#                   library_selection  library_source library_strategy  \
# entity:miniseq_id
# 21-00368644                  RANDOM         GENOMIC              WGS
# 21-00368644b                    NaN             NaN              NaN
#
#                                organism  platform        title
# entity:miniseq_id
# 21-00368644        Campylobacter jejuni  ILLUMINA  WGS of HAIs
# 21-00368644b                        NaN       NaN          NaN
#
# [2 rows x 41 columns]

# %%
# Just guessing here, but this seems right
id_map['21-00368644A'] = '21-00368644'
id_map['21-00368644B'] = '21-00368644b'

# %%
assert set(id_map.keys()) == set(set4.index)
assert set(id_map.values()).issubset(ag.index)

# %%
ag2 = ag.loc[[id_map[set4_id] for set4_id in set4.index]]
ag2 = ag2.reset_index().set_index(set4.index)

# %% [markdown]
# ## Inspect

# %%
bs_acc = ag2['biosample_accession']

# %% [markdown]
# ### Duplicated biosample

# %%
ag2[bs_acc.duplicated(keep=False) & ~bs_acc.isnull()]
# Out:
#              entity:miniseq_id biosample_accession submission_id  \
# id
# PNUSAE019069      PNUSAE019069        SAMN10182651           NaN
# PNUSAE020883      PNUSAE020883        SAMN10182651           NaN
#
#                                         amrfinderplus_amr_genes  \
# id
# PNUSAE019069  emrD,aadA1,sat2,dfrA1,blaEC,blaOXA-1,catA1,aph...
# PNUSAE020883  erm(B),emrD,qnrS1,tet(B),blaEC,mph(A),sul1,aad...
#
#              ts_mlst_predicted_st gambit_predicted_taxon city received_date  \
# id
# PNUSAE019069                ST245      Shigella flexneri  NaN           NaT
# PNUSAE020883                ST245      Shigella flexneri  NaN           NaT
#
#              Provider collection_date  ... isolation_type  lat_lon  \
# id                                     ...
# PNUSAE019069      NaN             NaT  ...            NaN      NaN
# PNUSAE020883      NaN             NaT  ...            NaN      NaN
#
#               library_ID library_layout library_selection library_source  \
# id
# PNUSAE019069         NaN            NaN               NaN            NaN
# PNUSAE020883         NaN            NaN               NaN            NaN
#
#               library_strategy organism platform title
# id
# PNUSAE019069               NaN      NaN      NaN   NaN
# PNUSAE020883               NaN      NaN      NaN   NaN
#
# [2 rows x 42 columns]

# %% [markdown]
# ### Biosample accession pattern

# %%
ag2[~bs_acc.str.match(r'SAMN\d+', na=True)]
# Out:
#             entity:miniseq_id biosample_accession submission_id  \
# id
# 21-00372063       21-00372063             QC Fail           NaN
#
#                                        amrfinderplus_amr_genes  \
# id
# 21-00372063  acrF,emrD,blaEC,tet(A),aph(3'')-Ib,aph(6)-Id,mdtM
#
#             ts_mlst_predicted_st gambit_predicted_taxon         city  \
# id
# 21-00372063      No ST predicted       Escherichia coli  Carson City
#
#             received_date                            Provider collection_date  \
# id
# 21-00372063    2021-07-13  Carson - Tahoe Regional Healthcare      2021-07-09
#
#              ... isolation_type  lat_lon  library_ID library_layout  \
# id           ...
# 21-00372063  ...            NaN      NaN         NaN            NaN
#
#             library_selection library_source  library_strategy organism  \
# id
# 21-00372063               NaN            NaN               NaN      NaN
#
#             platform title
# id
# 21-00372063      NaN   NaN
#
# [1 rows x 42 columns]

# %%
ag2['jared_notes'] = None

# %%
id_ = '21-00372063'

ag2.loc[id_, 'jared_notes'] = ag2.loc[id_, 'biosample_accession']
ag2.loc[id_, 'biosample_accession'] = None

# %% [markdown]
# ### Null biosample

# %%
ag2[bs_acc.isnull()]
# Out:
#               entity:miniseq_id biosample_accession     submission_id  \
# id
# 03-98DDCS             03-98DDCS                 NaN               NaN
# 0398KL                   0398KL                 NaN               NaN
# 1658-pos               1658-pos                 NaN               NaN
# 1736855-UT           1736855-UT                 NaN               NaN
# 21-00368644B       21-00368644b                 NaN               NaN
# 21-00372063         21-00372063                None               NaN
# 22-00020994         22-00020994                 NaN               NaN
# 22-00044713         22-00044713                 NaN  NV_NSPHL_0000491
# 249842-H2             249842-H2                 NaN  NV_NSPHL_0000545
# C6472DDCS             C6472DDCS                 NaN               NaN
# C6472KL                 C6472KL                 NaN               NaN
# CapA                       CapA                 NaN               NaN
# CapB                       CapB                 NaN               NaN
# CapC                       CapC                 NaN               NaN
# CapD                       CapD                 NaN               NaN
# CDC03-98CL           CDC03-98CL                 NaN               NaN
# CDC03-98sm           CDC03-98sm                 NaN               NaN
# D5480DS                 D5480DS                 NaN               NaN
# D5480KL                 D5480KL                 NaN               NaN
# ECP19-198ag         ECP19-198ag                 NaN               NaN
# ECP19-2498ag       ECP19-2498ag                 NaN               NaN
# ECP19-598ag         ECP19-598ag                 NaN               NaN
# ECP19-798ag         ECP19-798ag                 NaN               NaN
# EP21-3018AG         EP21-3018AG                 NaN               NaN
# EP21-5149AG         EP21-5149AG                 NaN               NaN
# EP21-6898AG         EP21-6898AG                 NaN               NaN
# F5828KL                 F5828KL                 NaN               NaN
# H8394DDCS             H8394DDCS                 NaN               NaN
# H8394KL                 H8394KL                 NaN               NaN
# K3430DDCS             K3430DDCS                 NaN               NaN
# PNUSAE014312a     PNUSAE014312a                 NaN               NaN
# PNUSAE014312b     PNUSAE014312b                 NaN               NaN
# PNUSAE014312       PNUSAE014312                 NaN  NV_NSPHL_0000548
# TB-Control           TB-Control                 NaN               NaN
#
#                                          amrfinderplus_amr_genes  \
# id
# 03-98DDCS                                   blaEC,emrD,acrF,mdtM
# 0398KL                                      mdtM,blaEC,emrD,acrF
# 1658-pos       oqxA,oqxB,fosA,emrD,kdeA,blaSHV-28,blaCTX-M-15...
# 1736855-UT                                           blaA,vat(F)
# 21-00368644B                                              blaOXA
# 21-00372063    acrF,emrD,blaEC,tet(A),aph(3'')-Ib,aph(6)-Id,mdtM
# 22-00020994          No AMR genes detected by NCBI-AMRFinderPlus
# 22-00044713          No AMR genes detected by NCBI-AMRFinderPlus
# 249842-H2      blaSHV-11,oqxB,oqxA,fosA7,emrD,kdeA,fosA,tet(A...
# C6472DDCS                    mdsA,mdsB,fosA7,aadA1,sul1,blaTEM-1
# C6472KL                      fosA7,mdsA,mdsB,aadA1,sul1,blaTEM-1
# CapA                                     aac(2')-Ic,blaA,erm(37)
# CapB                                     aac(2')-Ic,blaA,erm(37)
# CapC                                     aac(2')-Ic,erm(37),blaA
# CapD                                     aac(2')-Ic,blaA,erm(37)
# CDC03-98CL                                  mdtM,blaEC,emrD,acrF
# CDC03-98sm                                  mdtM,blaEC,emrD,acrF
# D5480DS                                               blaOXA-193
# D5480KL                                               blaOXA-193
# ECP19-198ag                                 mdtM,blaEC,acrF,emrD
# ECP19-2498ag                       acrF,blaEC,blaTEM-1,mdtM,emrD
# ECP19-598ag                                 mdtM,blaEC,emrD,acrF
# ECP19-798ag                                 mdtM,blaEC,acrF,emrD
# EP21-3018AG                                 mdtM,acrF,emrD,blaEC
# EP21-5149AG                                 acrF,blaEC,mdtM,emrD
# EP21-6898AG                                 mdtM,emrD,acrF,blaEC
# F5828KL                          blaCARB-18,catC,tet(35),tet(34)
# H8394DDCS                                               lin,fosX
# H8394KL                                                 lin,fosX
# K3430DDCS                        blaCARB-18,tet(35),catC,tet(34)
# PNUSAE014312a                      blaEC,emrD,acrF,mdtM,blaTEM-1
# PNUSAE014312b  emrD,acrF,mdtM,blaEC,tet(B),catA1,blaOXA-1,aad...
# PNUSAE014312   emrD,acrF,mdtM,blaEC,tet(B),catA1,blaOXA-1,aad...
# TB-Control                               aac(2')-Ic,erm(37),blaA
#
#               ts_mlst_predicted_st      gambit_predicted_taxon           city  \
# id
# 03-98DDCS                     ST11            Escherichia coli            NaN
# 0398KL                        ST11            Escherichia coli            NaN
# 1658-pos                      ST14       Klebsiella pneumoniae            NaN
# 1736855-UT         No ST predicted     Yersinia enterocolitica            NaN
# 21-00368644B                  ST50        Campylobacter jejuni            NaN
# 21-00372063        No ST predicted            Escherichia coli    Carson City
# 22-00020994        No ST predicted               Campylobacter        Phoenix
# 22-00044713        No ST predicted             Actinomyces spp  not collected
# 249842-H2          No ST predicted       Klebsiella pneumoniae  not collected
# C6472DDCS                     ST15         Salmonella enterica            NaN
# C6472KL                       ST15         Salmonella enterica            NaN
# CapA                         ST215  Mycobacterium tuberculosis            NaN
# CapB                         ST215  Mycobacterium tuberculosis            NaN
# CapC                         ST268  Mycobacterium tuberculosis            NaN
# CapD                         ST277  Mycobacterium tuberculosis            NaN
# CDC03-98CL                    ST11            Escherichia coli            NaN
# CDC03-98sm                    ST11            Escherichia coli            NaN
# D5480DS                       ST22        Campylobacter jejuni            NaN
# D5480KL                       ST22        Campylobacter jejuni            NaN
# ECP19-198ag                   ST11            Escherichia coli            NaN
# ECP19-2498ag                  ST11            Escherichia coli            NaN
# ECP19-598ag                   ST11            Escherichia coli            NaN
# ECP19-798ag                   ST11            Escherichia coli            NaN
# EP21-3018AG                   ST21            Escherichia coli            NaN
# EP21-5149AG                   ST17            Escherichia coli            NaN
# EP21-6898AG                   ST16            Escherichia coli            NaN
# F5828KL                      ST933     Vibrio parahaemolyticus            NaN
# H8394DDCS                      ST1      Listeria monocytogenes            NaN
# H8394KL                        ST1      Listeria monocytogenes            NaN
# K3430DDCS                    ST933     Vibrio parahaemolyticus            NaN
# PNUSAE014312a               ST2025            Escherichia coli            NaN
# PNUSAE014312b      No ST predicted            Escherichia coli            NaN
# PNUSAE014312       No ST predicted            Escherichia coli  not collected
# TB-Control                     NaN  Mycobacterium tuberculosis            NaN
#
#               received_date                            Provider  \
# id
# 03-98DDCS               NaT                                 NaN
# 0398KL                  NaT                                 NaN
# 1658-pos                NaT                                 NaN
# 1736855-UT              NaT                                 NaN
# 21-00368644B            NaT                                 NaN
# 21-00372063      2021-07-13  Carson - Tahoe Regional Healthcare
# 22-00020994      2022-01-20   Laboratory Corporation of America
# 22-00044713             NaT                                 NaN
# 249842-H2               NaT                                 NaN
# C6472DDCS               NaT                                 NaN
# C6472KL                 NaT                                 NaN
# CapA                    NaT                                 NaN
# CapB                    NaT                                 NaN
# CapC                    NaT                                 NaN
# CapD                    NaT                                 NaN
# CDC03-98CL              NaT                                 NaN
# CDC03-98sm              NaT                                 NaN
# D5480DS                 NaT                                 NaN
# D5480KL                 NaT                                 NaN
# ECP19-198ag             NaT                                 NaN
# ECP19-2498ag            NaT                                 NaN
# ECP19-598ag             NaT                                 NaN
# ECP19-798ag             NaT                                 NaN
# EP21-3018AG             NaT                                 NaN
# EP21-5149AG             NaT                                 NaN
# EP21-6898AG             NaT                                 NaN
# F5828KL                 NaT                                 NaN
# H8394DDCS               NaT                                 NaN
# H8394KL                 NaT                                 NaN
# K3430DDCS               NaT                                 NaN
# PNUSAE014312a           NaT                                 NaN
# PNUSAE014312b           NaT                                 NaN
# PNUSAE014312            NaT                                 NaN
# TB-Control              NaT                                 NaN
#
#               collection_date  ...        lat_lon        library_ID  \
# id                             ...
# 03-98DDCS                 NaT  ...            NaN               NaN
# 0398KL                    NaT  ...            NaN               NaN
# 1658-pos                  NaT  ...            NaN               NaN
# 1736855-UT                NaT  ...            NaN               NaN
# 21-00368644B              NaT  ...            NaN               NaN
# 21-00372063        2021-07-09  ...            NaN               NaN
# 22-00020994        2022-01-13  ...  not collected  NV_NSPHL_0000449
# 22-00044713        2022-02-27  ...  not collected  NV_NSPHL_0000491
# 249842-H2          2020-10-23  ...  not collected  NV_NSPHL_0000545
# C6472DDCS                 NaT  ...            NaN               NaN
# C6472KL                   NaT  ...            NaN               NaN
# CapA                      NaT  ...            NaN               NaN
# CapB                      NaT  ...            NaN               NaN
# CapC                      NaT  ...            NaN               NaN
# CapD                      NaT  ...            NaN               NaN
# CDC03-98CL                NaT  ...            NaN               NaN
# CDC03-98sm                NaT  ...            NaN               NaN
# D5480DS                   NaT  ...            NaN               NaN
# D5480KL                   NaT  ...            NaN               NaN
# ECP19-198ag               NaT  ...            NaN               NaN
# ECP19-2498ag              NaT  ...            NaN               NaN
# ECP19-598ag               NaT  ...            NaN               NaN
# ECP19-798ag               NaT  ...            NaN               NaN
# EP21-3018AG               NaT  ...            NaN               NaN
# EP21-5149AG               NaT  ...            NaN               NaN
# EP21-6898AG               NaT  ...            NaN               NaN
# F5828KL                   NaT  ...            NaN               NaN
# H8394DDCS                 NaT  ...            NaN               NaN
# H8394KL                   NaT  ...            NaN               NaN
# K3430DDCS                 NaT  ...            NaN               NaN
# PNUSAE014312a             NaT  ...            NaN               NaN
# PNUSAE014312b             NaT  ...            NaN               NaN
# PNUSAE014312              NaT  ...  not collected  NV_NSPHL_0000548
# TB-Control                NaT  ...            NaN               NaN
#
#                library_layout library_selection library_source  \
# id
# 03-98DDCS                 NaN               NaN            NaN
# 0398KL                    NaN               NaN            NaN
# 1658-pos                  NaN               NaN            NaN
# 1736855-UT                NaN               NaN            NaN
# 21-00368644B              NaN               NaN            NaN
# 21-00372063               NaN               NaN            NaN
# 22-00020994            paired            RANDOM        GENOMIC
# 22-00044713            paired            RANDOM        GENOMIC
# 249842-H2              paired            RANDOM        GENOMIC
# C6472DDCS                 NaN               NaN            NaN
# C6472KL                   NaN               NaN            NaN
# CapA                      NaN               NaN            NaN
# CapB                      NaN               NaN            NaN
# CapC                      NaN               NaN            NaN
# CapD                      NaN               NaN            NaN
# CDC03-98CL                NaN               NaN            NaN
# CDC03-98sm                NaN               NaN            NaN
# D5480DS                   NaN               NaN            NaN
# D5480KL                   NaN               NaN            NaN
# ECP19-198ag               NaN               NaN            NaN
# ECP19-2498ag              NaN               NaN            NaN
# ECP19-598ag               NaN               NaN            NaN
# ECP19-798ag               NaN               NaN            NaN
# EP21-3018AG               NaN               NaN            NaN
# EP21-5149AG               NaN               NaN            NaN
# EP21-6898AG               NaN               NaN            NaN
# F5828KL                   NaN               NaN            NaN
# H8394DDCS                 NaN               NaN            NaN
# H8394KL                   NaN               NaN            NaN
# K3430DDCS                 NaN               NaN            NaN
# PNUSAE014312a             NaN               NaN            NaN
# PNUSAE014312b             NaN               NaN            NaN
# PNUSAE014312           paired            RANDOM        GENOMIC
# TB-Control                NaN               NaN            NaN
#
#               library_strategy               organism  platform        title  \
# id
# 03-98DDCS                  NaN                    NaN       NaN          NaN
# 0398KL                     NaN                    NaN       NaN          NaN
# 1658-pos                   NaN                    NaN       NaN          NaN
# 1736855-UT                 NaN                    NaN       NaN          NaN
# 21-00368644B               NaN                    NaN       NaN          NaN
# 21-00372063                NaN                    NaN       NaN          NaN
# 22-00020994                WGS     Campylobacter lari  ILLUMINA  WGS of HAIs
# 22-00044713                WGS        Actinomyces spp  ILLUMINA  WGS of HAIs
# 249842-H2                  WGS  Klebsiella pneumoniae  ILLUMINA  WGS of HAIs
# C6472DDCS                  NaN                    NaN       NaN          NaN
# C6472KL                    NaN                    NaN       NaN          NaN
# CapA                       NaN                    NaN       NaN          NaN
# CapB                       NaN                    NaN       NaN          NaN
# CapC                       NaN                    NaN       NaN          NaN
# CapD                       NaN                    NaN       NaN          NaN
# CDC03-98CL                 NaN                    NaN       NaN          NaN
# CDC03-98sm                 NaN                    NaN       NaN          NaN
# D5480DS                    NaN                    NaN       NaN          NaN
# D5480KL                    NaN                    NaN       NaN          NaN
# ECP19-198ag                NaN                    NaN       NaN          NaN
# ECP19-2498ag               NaN                    NaN       NaN          NaN
# ECP19-598ag                NaN                    NaN       NaN          NaN
# ECP19-798ag                NaN                    NaN       NaN          NaN
# EP21-3018AG                NaN                    NaN       NaN          NaN
# EP21-5149AG                NaN                    NaN       NaN          NaN
# EP21-6898AG                NaN                    NaN       NaN          NaN
# F5828KL                    NaN                    NaN       NaN          NaN
# H8394DDCS                  NaN                    NaN       NaN          NaN
# H8394KL                    NaN                    NaN       NaN          NaN
# K3430DDCS                  NaN                    NaN       NaN          NaN
# PNUSAE014312a              NaN                    NaN       NaN          NaN
# PNUSAE014312b              NaN                    NaN       NaN          NaN
# PNUSAE014312               WGS       Escherichia coli  ILLUMINA  WGS of HAIs
# TB-Control                 NaN                    NaN       NaN          NaN
#
#               jared_notes
# id
# 03-98DDCS            None
# 0398KL               None
# 1658-pos             None
# 1736855-UT           None
# 21-00368644B         None
# 21-00372063       QC Fail
# 22-00020994          None
# 22-00044713          None
# 249842-H2            None
# C6472DDCS            None
# C6472KL              None
# CapA                 None
# CapB                 None
# CapC                 None
# CapD                 None
# CDC03-98CL           None
# CDC03-98sm           None
# D5480DS              None
# D5480KL              None
# ECP19-198ag          None
# ECP19-2498ag         None
# ECP19-598ag          None
# ECP19-798ag          None
# EP21-3018AG          None
# EP21-5149AG          None
# EP21-6898AG          None
# F5828KL              None
# H8394DDCS            None
# H8394KL              None
# K3430DDCS            None
# PNUSAE014312a        None
# PNUSAE014312b        None
# PNUSAE014312         None
# TB-Control           None
#
# [34 rows x 43 columns]

# %% [markdown]
# ## Output

# %%
ag2.to_csv(outfiles['table'])
